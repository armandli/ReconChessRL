# %%
import torch
from senseis.learning.rc_qconfig import SenseConfig2
from senseis.learning.rc_sense_trainer2 import RCSenseTrainer2
from senseis.reporters.rc_reporter import RCEpisodicReporter

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')
cpu = torch.device('cpu')

# %%
config = SenseConfig2(
    device=device,
    sense_model_filename='../models/rc_sense_model_v4.pt',
    episodes=4,
    iterations=2,
    eb_size=2,
    batchsize=2,
    learning_rate=0.0001,
    weight_decay=0.000001,
    pg_epsilon=0.00000001,
    sense_hidden_size=32
)

# %%
reporter = RCEpisodicReporter(config.batchsize, 1, 1)

# %%
trainer = RCSenseTrainer2(config, reporter)

# %%
trainer.train()
# Out:
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# r n b q . b n r
# p p . . b p P p
# . . n . . . . .
# . . . p . . . .
# . . . p . . . .
# . . P . . . . .
# P P . N P P P P
# R . B Q K B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# r n b q . b n r
# p p . . b p P p
# . . n . . . . .
# . . . . . . . .
# . . . p . . . .
# . . P . . . . .
# P P . N P P P P
# R . B Q K B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . r . . . k r
# p p . . q p b .
# . . . . . . . .
# . . p . . . . .
# . . . . . . . p
# . . . . P . . .
# P P . . B P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . r . . . k r
# p p . . . p b .
# . . . q . . . .
# . . p . . . . .
# . . . . . . . p
# . . . . P . . .
# P P . . B P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . r . . b k r
# p p . . . p . .
# . . . q . . . .
# . . p . . . . .
# . . . . . . . p
# . . . . P . . .
# P P . . B P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . r . . b k r
# . p . . . p . .
# p . . q . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . B P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . r q . b k .
# . p . . . p . .
# p . . . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . B P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . q . b k .
# . p . . . p . .
# p . r . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . . P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . q . b . .
# . p . . . . . k
# p . r . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . . P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . q . . . .
# . p . . . . b k
# p . r . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . . P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . . . . B .
# . p . . . . b .
# p . r . . . . .
# . . p . . . N .
# . . . . . . . R
# . . . . P . . P
# P P . . . P P .
# . R . . . . K R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . q . . . .
# . p . . . . b k
# p . r . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# P P . . . P P P
# R . . . . B N R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . . . . B .
# . p . . . . b .
# p . r . . . . .
# . . p . . . N .
# . . . . . . . R
# . . . . P . . P
# P P . . . P P .
# . R . . . . K R
# stockfish died: engine process died unexpectedly (exit code: 3221225477)
# board
# . . . . . . . .
# . p . . . . b k
# p . r . . . . .
# . . p . . . . .
# . . . . . . . .
# . . . q P . . .
# P P . . . P P P
# R . . . . . N R
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 0, 0/2: -0.040860190987586975
# Sense Episode 0, 0/2: -0.042584147304296494
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 1, 0/2: 0.02905847132205963
# Sense Episode 1, 0/2: 0.027383945882320404
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 2, 0/2: -0.022653579711914062
# Sense Episode 2, 0/2: -0.024465465918183327
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 3, 0/2: -0.009803468361496925
# Sense Episode 3, 0/2: -0.011802781373262405
