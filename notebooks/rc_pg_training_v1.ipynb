# %%
import torch
from senseis.learning.rc_qconfig import PGConfig
from senseis.learning.rc_pg_trainer1 import RCPGTrainer1
from senseis.reporters.rc_reporter import RCEpisodicReporter

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')
cpu = torch.device('cpu')

# %%
config = PGConfig(
    device=device,
    action_model_filename='../models/rc_action_model_v5.pt',
    sense_model_filename='../models/rc_sense_model_v5.pt',
    episodes=2048,
    iterations=2,
    eb_size=256,
    batchsize=128,
    learning_rate=0.0001,
    weight_decay=0.000001,
    pg_epsilon=0.00000001,
    action_hidden_size=384,
    sense_hidden_size=384
)

# %%
reporter = RCEpisodicReporter(config.batchsize, 1, 1)

# %%
trainer = RCPGTrainer1(config, reporter)

# %%
trainer.train()
# Out:
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 127, 128/256: -2.777589797973633
# Sense Episode 127, 128/256: -2.785322904586792
# Action Episode 127, 128/256: -0.013421710580587387
# Action Episode 127, 128/256: 0.008033848367631435
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 255, 128/256: -2.147716760635376
# Sense Episode 255, 128/256: -2.0500590801239014
# Action Episode 255, 128/256: 0.022533245384693146
# Action Episode 255, 128/256: -0.059719886630773544
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# Sense Episode 383, 128/256: -2.900815010070801
# Sense Episode 383, 128/256: -2.908308267593384
# Action Episode 383, 128/256: 0.0072320071049034595
# Action Episode 383, 128/256: -0.1251482218503952
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# Sense Episode 511, 128/256: -2.970540761947632
# Sense Episode 511, 128/256: -2.9567933082580566
# Action Episode 511, 128/256: 0.036843910813331604
# Action Episode 511, 128/256: -0.12123917788267136
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 639, 128/256: -3.169052839279175
# Sense Episode 639, 128/256: -3.2082743644714355
# Action Episode 639, 128/256: 0.027220632880926132
# Action Episode 639, 128/256: 0.07805973291397095
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# Sense Episode 767, 128/256: -2.3802998065948486
# Sense Episode 767, 128/256: -2.4573886394500732
# Action Episode 767, 128/256: -0.018859190866351128
# Action Episode 767, 128/256: -0.08698277175426483
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# Sense Episode 895, 128/256: -2.4491372108459473
# Sense Episode 895, 128/256: -2.29379940032959
# Action Episode 895, 128/256: 0.13958419859409332
# Action Episode 895, 128/256: 0.019336452707648277
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# ...
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# Sense Episode 1791, 128/256: -2.6665775775909424
# Sense Episode 1791, 128/256: -2.6121718883514404
# Action Episode 1791, 128/256: -0.07755419611930847
# Action Episode 1791, 128/256: -0.02144404500722885
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 1919, 128/256: -2.9804470539093018
# Sense Episode 1919, 128/256: -2.847452163696289
# Action Episode 1919, 128/256: -0.07346771657466888
# Action Episode 1919, 128/256: -0.0607532300055027
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner False win reason WinReason.KING_CAPTURE
# winner True win reason WinReason.KING_CAPTURE
# Sense Episode 2047, 128/256: -3.097604990005493
# Sense Episode 2047, 128/256: -3.0754873752593994
# Action Episode 2047, 128/256: -0.004890725947916508
# Action Episode 2047, 128/256: -0.10511712729930878
